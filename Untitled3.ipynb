# %%
import subprocess
import sys

# Launch Streamlit in the background so your notebook stays usable
subprocess.Popen([sys.executable, "-m", "streamlit", "run", "dashboard.py"])
# Out:
# <Popen: returncode: None args: ['/Users/farnaz/.pyenv/versions/3.10.0/bin/py...>
#       👋 Welcome to Streamlit!
#
#       If you'd like to receive helpful onboarding emails, news, offers, promotions,
#       and the occasional swag, please enter your email address below. Otherwise,
#       leave this field blank.
#
#       Email:
# 2025-11-17 15:23:03.455

# %%
import os
current_path = os.getcwd()
print(current_path)
# Out:
# /Users/farnaz/STCK

# %%
cd /Users/farnaz/STCK


🔐 If you want, I can also add:
✔ Password protection (so only you can access it)
✔ A fixed custom URL (permanent, never changes)
✔ Auto-start on Mac boot
✔ A custom subdomain (like farnaz-ticker.ai)

Just tell me:
“Yes, secure it + make URL permanent.”
